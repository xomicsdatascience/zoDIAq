# %% [markdown]
# # Determing Optimal Match Number for FDR Calculations (library peak max = 31)

# %%
import pandas as pd
import re
from matplotlib import pyplot
import csodiaq_base_functions as cbf
import csodiaq_figure_functions as cff
import csodiaq_menu_functions as menu
import os
from matplotlib.font_manager import FontProperties
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Loading Results

# %%
files = list(os.listdir('Data/Output'))
removables = ['unfilteredPpmPerRow', 'filteredBestMatch', 'offset_SD', 'ppmSpread', 'ppmSpreadDecoy']
csodiaq = []
check = True
for f in files:
    for r in removables:
        if r in f:
            check = False
    if check:
        csodiaq.append('Data/Output/'+f)
    check = True
for x in csodiaq: print(x)
# Out:
# Data/Output/csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n1b.csv
# Data/Output/csodiaq_lib-human-20peaks-noloss-pt2mz-300to2000_exp-n1b.csv
# Data/Output/csodiaq_lib-iproph1-10peaks_exp-n1b.csv
# Data/Output/csodiaq_lib-iproph1-20peaks-highres_exp-n1b.csv
# Data/Output/csodiaq_lib-iproph1-10peaks_exp-n1b_corrected1.csv

# %%
for x in csodiaq: cff.write_meta_analysis_files(x)
listOfFiles = list(os.listdir('Data/Figures/FDRGraphs/'))
listOfFiles = ['Data/Figures/FDRGraphs/'+x for x in listOfFiles]
listOfFiles
# Out:
# ['Data/Figures/FDRGraphs/csodiaq_lib-human-20peaks-noloss-pt2mz-300to2000_exp-n1b_FDRGraph_spectral.csv',
#  'Data/Figures/FDRGraphs/csodiaq_lib-human-20peaks-noloss-pt2mz-300to2000_exp-n1b_FDRGraph_protein.csv',
#  'Data/Figures/FDRGraphs/csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FDRGraph_peptide.csv',
#  'Data/Figures/FDRGraphs/csodiaq_lib-iproph1-10peaks_exp-n1b_corrected1_FDRGraph_spectral.csv',
#  'Data/Figures/FDRGraphs/csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n1b_FDRGraph_spectral.csv',
#  'Data/Figures/FDRGraphs/csodiaq_lib-iproph1-10peaks_exp-n1b_FDRGraph_protein.csv',
#  'Data/Figures/FDRGraphs/csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n1b_FDRGraph_protein.csv',
#  'Data/Figures/FDRGraphs/csodiaq_lib-iproph1-10peaks_exp-n1b_corrected1_FDRGraph_protein.csv',
#  'Data/Figures/FDRGraphs/csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n1b_FDRGraph_peptide.csv',
#  'Data/Figures/FDRGraphs/csodiaq_lib-iproph1-10peaks_exp-n1b_FDRGraph_peptide.csv',
#  'Data/Figures/FDRGraphs/csodiaq_lib-iproph1-10peaks_exp-n1b_FDRGraph_spectral.csv',
#  'Data/Figures/FDRGraphs/csodiaq_lib-iproph1-10peaks_exp-n1b_corrected1_FDRGraph_peptide.csv',
#  'Data/Figures/FDRGraphs/csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FDRGraph_spectral.csv',
#  'Data/Figures/FDRGraphs/csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FDRGraph_protein.csv',
#  'Data/Figures/FDRGraphs/csodiaq_lib-human-20peaks-noloss-pt2mz-300to2000_exp-n1b_FDRGraph_peptide.csv']

# %%
def make_graph_df(listOfFiles):
    concatLists = []
    for file in listOfFiles:
        temp = pd.read_csv(file)
        groupName = re.sub('Data/Figures/FDRGraphs/(.*)\.csv', r'\1', file)
        temp['group'] = [groupName for x in range(len(temp))]
        concatLists.append(temp)
    return pd.concat(concatLists)

# %%
spectrum = make_graph_df([x for x in listOfFiles if 'spectral' in x])
spectrum
# Out:
#     matches  FDRCutoff    total    cosine  FDRDecoys  totalDecoys  \
# 0         4          0   323050  0.000000          0       117659
# 1         5          0   145598  0.000000          0        44296
# 2         6       3284    66022  0.992108         32        14820
# 3         7       9585    31832  0.973189         95         4388
# 4         8      10314    16973  0.943013        103         1186
# 5         9       8725     9934  0.883291         87          291
# 6        10       6100     6120  0.620446         61           64
# 7        11       3906     3906  0.512427         11           12
# 8        12       2556     2556  0.554348         -1            0
# 9        13       1672     1672  0.683474         -1            0
# 10       14       1119     1119  0.683474         -1            0
# 11       15        744      744  0.689010         -1            0
# 12       16        490      490  0.799978         -1            0
# 13       17        310      310  0.897423         -1            0
# 14       18        187      187  0.907163         -1            0
# 15       19         97       97  0.907163         -1            0
# 16       20         41       41  0.907163         -1            0
# 0         4          0   281290  0.000000          0        85639
# 1         5          0   111421  0.000000          0        23636
# 2         6       7753    49167  0.985544         77         5675
# 3         7      15016    25765  0.944482        150         1143
# 4         8      14578    14888  0.749461        145          170
# 5         9       7920     7920  0.485325         19           20
# 6        10       2905     2905  0.646612         -1            0
# 0         4          0   936555  0.000000          0       378005
# 3         7        342    395  0.979544          3            9
# 4         8        250    269  0.971438          2            3
# 5         9        161    161  0.937469         -1            0
# 6        10         68     68  0.942544         -1            0
# 0         4          0  15520  0.000000          0         7626
# 1         5          0   3724  0.000000          0         1556
# 2         6          0   1114  0.000000          0          297
# 3         7          0    482  0.000000          0           51
# 4         8        168    290  0.990723          1           13
# 5         9        201    201  0.833848          0            1
# 6        10        143    143  0.882865         -1            0
# 7        11         95     95  0.913521         -1            0
# 8        12         67     67  0.935049         -1            0
# 9        13         40     40  0.970606         -1            0
# 10       14         27     27  0.980460         -1            0
# 11       15         14     14  0.980460         -1            0
# 12       16          6      6  0.990723         -1            0
# 13       17          4      4  0.990723         -1            0
# 14       18          2      2  0.990723         -1            0
# 15       19          1      1  0.991513         -1            0
# 0         4          0  12377  0.000000          0         5654
# 1         5          0   2118  0.000000          0          605
# 2         6        253    676  0.995263          2           56
# 3         7        394    394  0.803786          2            3
# 4         8        266    266  0.895035          0            1
# 5         9        139    139  0.915343         -1            0
# 6        10         51     51  0.915343         -1            0
# 0         4          0  15913  0.000000          0         7872
# 1         5          0   4706  0.000000          0         2069
# 2         6          0   1635  0.000000          0          608
# 3         7          0    713  0.000000          0          194
# 4         8          0    370  0.000000          0           48
# 5         9          0    249  0.000000          0           11
# 6        10        200    202  0.901753          2            3
# 7        11        168    168  0.863470          0            1
# 8        12        136    136  0.863470         -1            0
# 9        13        110    110  0.922555         -1            0
# 10       14         76     76  0.940711         -1            0
# 11       15         49     49  0.940711         -1            0
# 12       16         36     36  0.951311         -1            0
# 13       17         21     21  0.980631         -1            0
# 14       18         10     10  0.990185         -1            0
# 15       19          4      4  0.990185         -1            0
#
#                                                 group
# 0   csodiaq_lib-human-20peaks-noloss-pt2mz-300to20...
# 1   csodiaq_lib-human-20peaks-noloss-pt2mz-300to20...
# 2   csodiaq_lib-human-20peaks-noloss-pt2mz-300to20...
# 3   csodiaq_lib-human-20peaks-noloss-pt2mz-300to20...
# 4   csodiaq_lib-human-20peaks-noloss-pt2mz-300to20...
# 5   csodiaq_lib-human-20peaks-noloss-pt2mz-300to20...
# 6   csodiaq_lib-human-20peaks-noloss-pt2mz-300to20...
# 7   csodiaq_lib-human-20peaks-noloss-pt2mz-300to20...
# 8   csodiaq_lib-human-20peaks-noloss-pt2mz-300to20...
# 9   csodiaq_lib-human-20peaks-noloss-pt2mz-300to20...
# 10  csodiaq_lib-human-20peaks-noloss-pt2mz-300to20...
# 11  csodiaq_lib-human-20peaks-noloss-pt2mz-300to20...
# 12  csodiaq_lib-human-20peaks-noloss-pt2mz-300to20...
# 0   csodiaq_lib-iproph1-10peaks_exp-n1b_FDRGraph_p...
# 1   csodiaq_lib-iproph1-10peaks_exp-n1b_FDRGraph_p...
# 2   csodiaq_lib-iproph1-10peaks_exp-n1b_FDRGraph_p...
# 3   csodiaq_lib-iproph1-10peaks_exp-n1b_FDRGraph_p...
# 4   csodiaq_lib-iproph1-10peaks_exp-n1b_FDRGraph_p...
# 5   csodiaq_lib-iproph1-10peaks_exp-n1b_FDRGraph_p...
# 6   csodiaq_lib-iproph1-10peaks_exp-n1b_FDRGraph_p...
# 0   csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n...
# 1   csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n...
# 2   csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n...
# 3   csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n...
# 4   csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n...
# 5   csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n...
# 6   csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n...
# 7   csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n...
# 8   csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n...
# 9   csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n...
# 10  csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n...
# 11  csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n...
# 12  csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n...
# 13  csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n...
# 14  csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n...
# 15  csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n...
# 0   csodiaq_lib-iproph1-10peaks_exp-n1b_corrected1...
# 1   csodiaq_lib-iproph1-10peaks_exp-n1b_corrected1...
# 2   csodiaq_lib-iproph1-10peaks_exp-n1b_corrected1...
# 3   csodiaq_lib-iproph1-10peaks_exp-n1b_corrected1...
# 4   csodiaq_lib-iproph1-10peaks_exp-n1b_corrected1...
# 5   csodiaq_lib-iproph1-10peaks_exp-n1b_corrected1...
# 6   csodiaq_lib-iproph1-10peaks_exp-n1b_corrected1...
# 0   csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FD...
# 1   csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FD...
# 2   csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FD...
# 3   csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FD...
# 4   csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FD...
# 5   csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FD...
# 6   csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FD...
# 7   csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FD...
# 8   csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FD...
# 9   csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FD...
# 10  csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FD...
# 11  csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FD...
# 12  csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FD...
# 13  csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FD...
# 14  csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FD...
# 15  csodiaq_lib-iproph1-20peaks-highres_exp-n1b_FD...

# %%
fontP = FontProperties()
fontP.set_size('xx-small')

# %% [markdown]
# ## Optimal FDR Cutoff

# %% [markdown]
# ### Spectral Level Analysis

# %%
spectrumFDR = spectrum.pivot(index='matches', columns='group', values='FDRCutoff')
spectrumFDR.plot()
pyplot.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

# %% [markdown]
# ### Peptide Level Analysis

# %%
peptideFDR = peptide.pivot(index='matches', columns='group', values='FDRCutoff')
peptideFDR.plot()
pyplot.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

# %% [markdown]
# ### Protein Level Analysis

# %%
proteinFDR = protein.pivot(index='matches', columns='group', values='FDRCutoff')
proteinFDR.plot()
pyplot.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

# %% [markdown]
# ## Percentage FDR Representation

# %% [markdown]
# ### Data Rearrangement

# %%
spectrum = spectrum.reset_index(drop=True)
peptide = spectrum.reset_index(drop=True)
protein = protein.reset_index(drop=True)

spectrum['%'] = [(spectrum['FDRCutoff'].loc[i]/spectrum['total'].loc[i]) for i in range(len(spectrum))]
peptide['%'] = [(peptide['FDRCutoff'].loc[i]/peptide['total'].loc[i]) for i in range(len(peptide))]
protein['%'] = [(protein['FDRCutoff'].loc[i]/protein['total'].loc[i]) for i in range(len(protein))]

# %% [markdown]
# ### Spectrum Level Analysis

# %%
spectrumPerc = spectrum.pivot(index='matches', columns='group', values='%')
spectrumPerc.plot()
pyplot.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

# %% [markdown]
# ### Peptide Level Analysis

# %%
peptidePerc = peptide.pivot(index='matches', columns='group', values='%')
peptidePerc.plot()
pyplot.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

# %% [markdown]
# ### Protein Level Analysis

# %%
proteinPerc = protein.pivot(index='matches', columns='group', values='%')
proteinPerc.plot()
pyplot.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

# %% [markdown]
# ## Cosine

# %% [markdown]
# ### Spectrum Level Analysis

# %%
spectrumCos = spectrum.pivot(index='matches', columns='group', values='cosine')
spectrumCos.plot()
pyplot.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

# %% [markdown]
# ### Peptide Level Analysis

# %%
peptideCos = peptide.pivot(index='matches', columns='group', values='cosine')
peptideCos.plot()
pyplot.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

# %% [markdown]
# ### Protein Level Analysis

# %%
proteinCos = protein.pivot(index='matches', columns='group', values='cosine')
proteinCos.plot()
pyplot.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

# %% [markdown]
# ## Decoys (total)

# %% [markdown]
# ### Spectral Level Analysis

# %%
spectrumDec = spectrum.pivot(index='matches', columns='group', values='totalDecoys')
p1 = spectrumDec.plot()
p1.set_ylim(0,1000)
pyplot.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

# %% [markdown]
# ### Peptide Level Analysis

# %%
peptideDec = peptide.pivot(index='matches', columns='group', values='totalDecoys')
p2 = peptideDec.plot()
p2.set_ylim(0,1000)
pyplot.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

# %% [markdown]
# ### Protein Level Analysis

# %%
proteinDec = protein.pivot(index='matches', columns='group', values='totalDecoys')
p3 = proteinDec.plot()
p3.set_ylim(0,1000)
pyplot.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)

# %% [markdown]
# ## Histograms With Decoys

# %% [markdown]
# ### Spectral Level Analysis

# %%
for x in csodiaq: menu.write_ppm_spread_decoy(x)
for x in csodiaq: 
    print(x)
    cff.draw_histogram_decoy(x)
# Out:
# #enter csodiaq ppm spread file creation:
# #0:01:48.260218
# 1
# 2
# 3
# 4
# 5
# #Complete
# #0:03:29.555227
# #enter csodiaq ppm spread file creation:
# #0:03:29.555413
# 1
# 2
# 3
# 4
# 5
# #Complete
# #0:04:01.718147
# #enter csodiaq ppm spread file creation:
# #0:04:01.718913
# 1
# 2
# 3
# 4
# 5
# #Complete
# #0:04:42.474639
# #enter csodiaq ppm spread file creation:
# #0:04:42.474728
# 1
# 2
# 3
# 4
# 5
# #Complete
# #0:06:59.856783
# #enter csodiaq ppm spread file creation:
# #0:06:59.857304
# 1
# 2
# 3
# 4
# 5
# #Complete
# #0:07:30.276931
# Data/Output/csodiaq_lib-iproph1-20peaks-noloss-pt2mz_exp-n1b.csv
# 2919313
# 1809779
# Data/Output/csodiaq_lib-human-20peaks-noloss-pt2mz-300to2000_exp-n1b.csv
# 1044108
# 535693
# Data/Output/csodiaq_lib-iproph1-10peaks_exp-n1b.csv
# 1436644
# 687225
# Data/Output/csodiaq_lib-iproph1-20peaks-highres_exp-n1b.csv
# 4325025
# 2788743
# Data/Output/csodiaq_lib-iproph1-10peaks_exp-n1b_corrected1.csv
# 964026
# 373200

# %% [markdown]
# ### Peptide Level Analysis

# %% [markdown]
# ### Protein Level Analysis
